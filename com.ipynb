# %%
from bs4 import BeautifulSoup
import requests
import pandas
import re
import execjs
print("https://www.haozu.com/sh/house-list/")
print("note:\n如果unitPrice==0，则totalPrice的单位为 元/间/月")
prefix = 'https://www.haozu.com/sh/house-list/'
allUrl = ['https://www.haozu.com/sh/house-list/']
for item in range(1, 1) : # 循环定义所需要爬取的地址
    if item != 1 :
        a = str(prefix) + 'o' + str(item)
        allUrl.append(a)
info = [] # 定义一个列表，用来装载字典,为了方便后面的数据整理
rule = re.compile("\d+\.?\d*") # define a regular of getting number from string

for url in allUrl : #loop url
#      #这是代理IP
#     proxy = {'http':'106.46.136.112:808'}
#     #创建ProxyHandler
#     proxy_support = request.ProxyHandler(proxy)
#     #创建Opener
#     opener = request.build_opener(proxy_support)
#     #添加User Angent
#     opener.addheaders = [('User-Agent','Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36')]
#     #安装OPener
#     request.install_opener(opener)
    headers={
            'Connection': 'Keep-Alive',
            'Accept': 'text/html, application/xhtml+xml, */*',
            'Accept-Language': 'en-US,en;q=0.8,zh-Hans-CN;q=0.5,zh-Hans;q=0.3',
            'User-Agent': 'Mozilla/5.0 (Windows NT 6.3; WOW64; Trident/7.0; rv:11.0) like Gecko'
        }
    res = requests.get(url,headers)
    res.encoding = 'utf-8'
    soup = BeautifulSoup(res.text,'html.parser')
    content = soup.select('.list-content')
    if len(content) == 0:  
        break
    for item in content:
        title = item.select('.h1-title a')[0].text
        
        area = item.select('.p1')[0].text.split('/')[1]
        area = re.search(rule,area)[0]
        
        totalPrice = item.select('.s1')[0].text 
        totalPrice = re.search(rule, totalPrice)
        totalPrice = float(totalPrice[0]) if totalPrice else 0
        totalPrice = totalPrice if totalPrice > 100 else totalPrice * 1000
         
        loc = item.select('.p1')[1].text.replace(' ','').replace('\n','')
        
        unitPrice = item.select('.s2')
        unitPrice = item.select('.s2')[0].text if unitPrice else '0'
        unitPrice = re.search(rule, unitPrice)
        unitPrice = float(unitPrice[0]) if unitPrice else 0

        # 获取详细信息
        href = item.select('a[style=""]')[0]['href']
        href = 'https://www.haozu.com' + href
        
        res = requests.get(href)
        res.encoding = 'utf-8'
        soup = BeautifulSoup(res.text,'html.parser')
        general = soup.select('.miaoshu-ul > .w50')
        
        register = general.select('s2')
        register =register[0].text if register else 'Error'
        
        
        print(register,href)
        info.append({'title': title,'area(m²)': area,'totalPrice(元)': totalPrice,'unitPrice(元 m²/day)': unitPrice, 'loc': loc})  
# pandas.DataFrame(info , columns=['title', 'area(m²)','loc','unitPrice(元 m²/day)','totalPrice(元)'])
info = sorted(info, key = lambda x : x['totalPrice(元)'], reverse=True) 

pandas.DataFrame(info)
#df.plot(kind='bar',x = 'loc',y = 'totalPrice(元)')

all = pandas.DataFrame(info)
all.to_excel('news.xlsx')
# Out:
# https://www.haozu.com/sh/house-list/
# note:
# 如果unitPrice==0，则totalPrice的单位为 元/间/月
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# c:\python\python36\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#
# c:\python\python36\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      79     if err is not None:
# ---> 80         raise err
#      81
#
# c:\python\python36\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      69                 sock.bind(source_address)
# ---> 70             sock.connect(sa)
#      71             return sock
#
# TimeoutError: [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# c:\python\python36\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# c:\python\python36\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#
# c:\python\python36\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     838         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 839             conn.connect()
#     840
#
# c:\python\python36\lib\site-packages\urllib3\connection.py in connect(self)
#     300         # Add certificate verification
# --> 301         conn = self._new_conn()
#     302         hostname = self.host
#
# c:\python\python36\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     167             raise NewConnectionError(
# --> 168                 self, "Failed to establish a new connection: %s" % e)
#     169
#
# NewConnectionError: <urllib3.connection.VerifiedHTTPSConnection object at 0x00000207530EE390>: Failed to establish a new connection: [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# c:\python\python36\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# c:\python\python36\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# c:\python\python36\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     397         if new_retry.is_exhausted():
# --> 398             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     399
#
# MaxRetryError: HTTPSConnectionPool(host='www.haozu.com', port=443): Max retries exceeded with url: /sh/house-list/?Connection=Keep-Alive&Accept=text%2Fhtml%2C+application%2Fxhtml%2Bxml%2C+%2A%2F%2A&Accept-Language=en-US%2Cen%3Bq%3D0.8%2Czh-Hans-CN%3Bq%3D0.5%2Czh-Hans%3Bq%3D0.3&User-Agent=Mozilla%2F5.0+%28Windows+NT+6.3%3B+WOW64%3B+Trident%2F7.0%3B+rv%3A11.0%29+like+Gecko (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x00000207530EE390>: Failed to establish a new connection: [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。',))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-16-8fb67663449a> in <module>
#      32             'User-Agent': 'Mozilla/5.0 (Windows NT 6.3; WOW64; Trident/7.0; rv:11.0) like Gecko'
#      33         }
# ---> 34     res = requests.get(url,headers)
#      35     res.encoding = 'utf-8'
#      36     soup = BeautifulSoup(res.text,'html.parser')
#
# c:\python\python36\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# c:\python\python36\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# c:\python\python36\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# c:\python\python36\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# c:\python\python36\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='www.haozu.com', port=443): Max retries exceeded with url: /sh/house-list/?Connection=Keep-Alive&Accept=text%2Fhtml%2C+application%2Fxhtml%2Bxml%2C+%2A%2F%2A&Accept-Language=en-US%2Cen%3Bq%3D0.8%2Czh-Hans-CN%3Bq%3D0.5%2Czh-Hans%3Bq%3D0.3&User-Agent=Mozilla%2F5.0+%28Windows+NT+6.3%3B+WOW64%3B+Trident%2F7.0%3B+rv%3A11.0%29+like+Gecko (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x00000207530EE390>: Failed to establish a new connection: [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。',))

# %%
# test
import re
ss = "aaa33.3,4343"
rule = re.compile("\d+\.?\d+")
s = re.findall(rule,ss)
print (s)

# %%
# selenium test
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

phdriver = "D:\\xsg\\app\\phantomjs-2.1.1-windows\\bin\\phantomjs.exe"
driver = webdriver.PhantomJS(drivercore)
driver.close()
driver.quit()
# chromedriver = "D:\\xsg\\app\\chromedriver_win32\\chromedriver.exe"
# chrome_options = Options()
# # 无头模式启动
# chrome_options.add_argument('--headless')
# # 谷歌文档提到需要加上这个属性来规避bug
# chrome_options.add_argument('--disable-gpu')
# # 初始化实例
# driver= webdriver.Chrome(executable_path= drivercore,chrome_options=chrome_options）

# %%
# selenium test
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

phdriver = "D:\\xsg\\app\\phantomjs-2.1.1-windows\\bin\\phantomjs.exe"
driver = webdriver.PhantomJS(phdriver)
driver.get("http://www.baidu.com/")
# driver.save_screenshot("baidu.png")
content = driver.page_source.encode('utf-8')
soup = BeautifulSoup(content,'html.parser')
driver.quit()

# %%
# -*- coding: UTF-8 -*-
from urllib import request
from bs4 import BeautifulSoup
if __name__ == "__main__":
    #访问网址
    url = 'https://www.haozu.com/sh/house-list/'
    #这是代理IP
    proxy = {'https':'171.37.155.176:8123'}
    #创建ProxyHandler
    proxy_support = request.ProxyHandler(proxy)
    #创建Opener
    opener = request.build_opener(proxy_support)
    #添加User Angent
    opener.addheaders = [('User-Agent','Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36')]
    #安装OPener
    request.install_opener(opener)
    #使用自己安装好的Opener
    print(request)
    response = request.urlopen(url)
    #读取相应信息并解码
    html = response.read().decode("utf-8")
    soup = BeautifulSoup(html,'html.parser').text
    #打印信息
    print(soup)
# Out:
# <module 'urllib.request' from 'c:\\python\\python36\\lib\\urllib\\request.py'>
#
#
#
#
#
# 【上海写字楼出租|上海办公楼|办公室租赁信息网】-上海好租网
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     .h1-title a:visited {color:#999;}/* 已被访问的链接 */
#
#
#     var _vds = _vds || [];
#     window._vds = _vds;
#     _vds.push(['setAccountId', 'b3bba5b4a5666905']);
#
#     (function () {
#         var bp = document.createElement('script');
#         var curProtocol = window.location.protocol.split(':')[0];
#         if (curProtocol === 'https') {
#             bp.src = 'https://zz.bdstatic.com/linksubmit/push.js';
#         }
#         else {
#             bp.src = 'http://push.zhanzhang.baidu.com/push.js';
#         }
#         var s = document.getElementsByTagName("script")[0];
#         s.parentNode.insertBefore(bp, s);
#
#         //growingio
# //        var vds = document.createElement('script');
# //        vds.type='text/javascript';
# //        vds.async = true;
# //        vds.src = ('https:' == document.location.protocol ? 'https://' : 'http://') + 'assets.growingio.com/vds.js';
# //        var s = document.getElementsByTagName('script')[0];
# //        s.parentNode.insertBefore(vds, s);
#     })();
#
#
#
#
#     var _paq = _paq || [];
#     _paq.push(["setDomains", ["*.www.haozu.com"]]);
#     _paq.push(['setDocumentTitle', "site"]);
#    _paq.push(['trackPageView']);
#    // _paq.push(['enableLinkTracking']);
#     (function() {
#         var u="//os.haozu.com/";
#         _paq.push(['setTrackerUrl', u+'sem']);
#         if(location.host=='cowork.haozu.com')
#             _paq.push(['setSiteId', 6]);
#         else
#              _paq.push(['setSiteId', 1]);
#         var d=document, g=d.createElement('script'), s=d.getElementsByTagName('script')[0];
#         g.type='text/javascript'; g.async=true; g.defer=true; g.src='//fang-oss.haozu.com/os/js/piwik.js'; s.parentNode.insertBefore(g,s);
#     })();
#
#
#
#
#
# 上海
# [切换城市]
#
# 北京上海广州深圳成都武汉杭州西安天津南京重庆长沙大连福州沈阳郑州无锡合肥
#
# |
#
#
# 首页
#
#
# 写字楼出租
# ·
# 出售
#
#
# 共享办公
#
#
# 好租自营
#
#
# 商铺出售
#
#
# 资讯
#
#
# 好租商城礼物
#
#
#
# 广告服务
#
#
# 投放房源
#
# |
#
#
#
#
# 扫码进入好租小程序
# ◆
#
#
#
#
#
#
# 扫码下载好租APP
# ◆
#
#
# |
#
# 电话：400-733-2233
# |
#
# 登录/注册
#
#
#
#
#
#
#
# 出租
#                         ◆
# ◆
#
#
#
# 找楼盘
#                         ◆
# ◆
#
#
#
# 共享办公
#                             ◆
# ◆
# hot
#
#
#
# 发现好房源
#                         ◆
# ◆
#
#
#
# 地图找房
#                         ◆
# ◆
#
#
#
# 委托找房
#                         ◆
# ◆
#
#
#
#
#
#
#
#
#
# 搜索
#
#
#
#
#
# 上海写字楼出租
#
#
#
#
#
# 位置：
#
#
# 区域
# 地铁
#
#
#
# 全部
# 浦东黄浦徐汇长宁静安普陀闸北虹口杨浦闵行宝山嘉定松江青浦奉贤上海周边
#
#
#
# 全部1号线2号线3号线4号线5号线6号线7号线8号线9号线10号线支线10号线主线11号线主线11号线支线12号线13号线16号线17号线磁悬浮
#
#
#
#
# 类型：
#
#
# 全部
# 普通办公
# 共享办公
# 创意园区
#
#
#
#
# 面积：
#
#
# 全部0-100m²100-300m²300-500m²500-1000m²1000m² 以上
#
#
# --
#
#
# m²
# 筛选
#
#
#
#
#
# 价格：
#
#
# 全部0-3元/m²⋅天3-4元/m²⋅天4-5元/m²⋅天5-7元/m²⋅天7-9元/m²⋅天9-12元/m²⋅天12元/m²⋅天以上
#
#
# --
#
#
#
# 筛选
#
#
# 按单价
#
# 按总价
#
#
#
#
#
#
# 装修：
#
#
# 全部豪华装修精装修中等装修简装修毛坯
#
#
#
# 品牌：
#
#
# 全部
# 米域
# 氪空间
# WE+酷窝
# 东朔
# 寰图
# 卓越E+
# 锦和
# 丰动力&F-space
#
#
#
#
# 特色：
#
#
# 可注册
# 地铁10分钟
# 带办公家具
# 热门楼盘
# 户型方正
# 免费车位
# 知名开发商
# 整栋
#
#
#
#
# 街道直达
#
#
#
# ABCDEFGHIJKLMNOPQRSTUVWXYZ
#
# 鞍山安亭半淞园路北京西路碧云北蔡八佰伴北新泾北外滩宝山路北桥白鹤堡镇城隍庙曹家渡昌平路漕宝路地铁漕河泾长桥川沙昌里曹路程家桥长阳路长白新村曹杨新村长寿路长风新村长征漕宝路春申曹王长兴岛城桥陈家镇崇明崇明新城漕泾车墩打浦桥董家渡打浦桥东明路东方路地铁东昌站地铁动物园大柏树东外滩大宁路东兰新村大场大华东城区大港洞泾复兴公园复兴公园枫林路复兴中路复旦大学凤溪封浜丰庄奉城枫泾方松高桥高行古北广中路光新甘泉路共和新路古美罗阳高境共富共康顾村干巷淮海路淮海中路黄浦滨江淮海路淮海中路衡山路华东理工淮海西路华泾湖南路航头合庆惠南花木虹桥火车站虹桥虹口足球场和平公园黄兴华师大和田虹桥航华虹梅路华漕黄渡华亭华新镇华新海湾海湾旅游区航头惠南横沙岛花桥江宁路静安寺建国西路交大金杨新村金桥江苏路地铁江苏路江湾金沙江路江川路静安新城金虹桥纪王锦秋花园金鹤新城菊园新区江桥嘉定城区嘉定新城嘉定镇金泽金汇金山中部金山新城金山卫金山工业园九亭嘉兴康健康桥控江路康桥昆山鲁班路老西门鲁班路龙华凌云路陆家嘴芦潮港龙阳路地铁站六里临港新城联洋鲁迅公园临平路临平和平公园凉城李子园老北站龙柏金汇老闵行罗南刘行罗店罗泾娄塘芦潮港临港新城吕巷练塘李塔汇梅园梅陇马桥庙行马陆泖港南外滩南京东路南京西路泥城南码头南方商城南翔南桥泥城蓬莱公园浦东外环平凉路彭浦浦江曲阳路七浦路蔷薇新村七宝七莘路青浦周边青浦新城青浦工业园区青浦北部人民广场茸北世博滨江世博滨江上海南站上师大世纪公园世纪大道上南新村上钢新村三林世博滨江上海影城四川北路四平路四平路石泉路上大水产路泗塘淞宝淞南石化山阳松江科技园松江老城松江新城松江工业区松江大学城佘山石湖荡泗泾苏州田林塘桥唐镇天山路提篮桥桃浦天目西路通河西城区通河新村唐行亭林天马山外滩五里桥五里桥万体馆外高桥王港潍坊五角场武宁路万里城汶水路吴泾吴淞外冈五厍新天地西藏南路新天地西康路新闸路襄阳南路斜土路徐家汇新场新华路仙霞新村新江湾城新华医院西藏北路新客站莘庄工业区莘庄新城徐行徐泾夏阳街道香花桥西渡新场新农小昆山新浜新桥莘闵豫园御桥源深竹园洋泾杨东杨浦公园杨浦大桥宜川路延长路杨行友谊路月浦叶榭永丰岳阳肇嘉浜路植物园竹园商贸区祝桥周浦周家渡张江中山公园镇宁路周家桥周家嘴路周家嘴路中原中山北路真如真光新村中远两湾城闸北公园芷江西路颛桥诸翟张庙朱桥真新新村重固赵巷赵屯朱家角柘林庄行周浦祝桥朱泾张堰朱行中山
#
#
#
#
#
#
#
#
#
# 成功
# 收藏成功
#
#
#
# close
#
# 收 藏
# 填写手机号，便于您在其他设备上查看
#
#
# 请输入正确的手机号
#
#
#
#
# 收 藏
# 收藏中
#
#
#
#
#
#
#     $(function(){
#         $('.menu_pos_filter').on('click', function(){
#             var data_div = $(this).data('type');
#             $('.menu_pos_filter').removeClass('cur');
#             $(this).addClass('cur');
#             $('.secsel').hide();
#             $('.'+data_div).show();
#         });
#     });
#
#
#
#
#
# 默认排序
# 单价
# 理想办公季·特惠房源
# 共有50057条房源满足您的需求
#
#
#
#
#
#
#
#
#
#
# 七莘路 丰树商业城 324.81平米 精装修
# 单价：4.8元/m²⋅天
#
# 丰树商业城 / 324.8m² / 精装修
# [闵行] - [七莘路]
#                             |
#                             顾戴路2337号                            ; 距离12号线七莘路站约235米
# 有396位用户正在浏览该房源
# 4.7万元/月
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 共富 泰德科技园 172.3平米 中等装修
# 单价：2.2元/m²⋅天
#
# 泰德科技园 / 172.3m² / 中等装修
# [宝山] - [共富]
#                             |
#                             蕰川路516号（地铁一号线共富新村站旁）                            ; 距离1号线共富新村站约253米
# 有8位用户正在浏览该房源
# 1.2万元/月
#
#
#
#
#
#
#
#
#
#
#
#
# 地铁10分钟
#
#
#
#
#
#
#
#
#
#
# 七莘路 旭辉·莘庄中心 2363平米 精装修
# 单价：4.3元/m²⋅天
#
# 旭辉·莘庄中心 / 2363m² / 精装修
# [闵行] - [七莘路]
#                             |
#                             秀文路园秀路路口西150米                            ; 距离12号线七莘路站约1059米
# 30.9万元/月
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 航头 万香（上海）创新港 151平米
# 单价：1.8元/m²⋅天
#
# 万香（上海）创新港 / 151m²
# [浦东] - [航头]
#                             |
#                             航头镇航都路18号
# 有25位用户正在浏览该房源
# 8267元/月
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 共富 泰德科技园 294.67平米
# 单价：2.4元/m²⋅天
#
# 泰德科技园 / 294.7m²
# [宝山] - [共富]
#                             |
#                             蕰川路516号（地铁一号线共富新村站旁）                            ; 距离1号线共富新村站约253米
# 有38位用户正在浏览该房源
# 2.2万元/月
#
#
#
#
#
#
#
#
#
#
#
#
# 地铁10分钟
#
#
#
#
#
#
#
#
#
#
# 大柏树 复城国际898号大楼 190平米 中等装修
# 单价：3.5元/m²⋅天
#
# 复城国际898号大楼 / 190m² / 中等装修
# [虹口] - [大柏树]
#                             |
#                             曲阳路898                            ; 距离3号线大柏树站约792米
# 有16位用户正在浏览该房源
# 2万元/月
#
#
#
#
#
#
#
#
#
#
#
#
# 知名物业
#
#
#
#
#
#
#
#
#
#
# 南翔 运通星财富广场 243平米 精装修
# 单价：2.2元/m²⋅天
#
# 运通星财富广场 / 243m² / 精装修
# [嘉定] - [南翔]
#                             |
#                             众仁路399号                            ; 距离11号线主线南翔站约791米
# 有35位用户正在浏览该房源
# 1.6万元/月
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 嘉定新城 创源新城TEEC上海中心大厦 440平米 精装修
# 单价：3元/m²⋅天
#
# 创源新城TEEC上海中心大厦 / 440m² / 精装修
# [嘉定] - [嘉定新城]
#                             |
#                             云谷路599弄                            ; 距离11号线主线嘉定新城站约290米
# 有8位用户正在浏览该房源
# 4万元/月
#
#
#
#
#
#
#
#
#
#
#
#
# 地铁10分钟
#
#
#
#
#
#
#
#
#
#
# 江桥 歆翱国际电商大厦 1380平米 精装修
# 单价：2元/m²⋅天
#
# 歆翱国际电商大厦 / 1380m² / 精装修
# [嘉定] - [江桥]
#                             |
#                             爱特路855号、866号                            ; 距离13号线金运路站约1955米
# 有17位用户正在浏览该房源
# 8.4万元/月
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 火车站 嘉里不夜城 120平米 精装修
# 单价：5.2元/m²⋅天
#
# 嘉里不夜城 / 120m² / 精装修
# [闸北] - [火车站]
#                             |
#                             天目西路218号                            ; 距离1号线上海火车站站约265米
# 有14位用户正在浏览该房源
# 1.9万元/月
#
#
#
#
#
#
#
#
#
#
#
#
# 带办公家具户型方正有钥匙
#
#
#
#
#
#
#
#
#
#
# 共富 泰德科技园 241.92平米 中等装修
# 单价：2.5元/m²⋅天
#
# 泰德科技园 / 241.9m² / 中等装修
# [宝山] - [共富]
#                             |
#                             蕰川路516号（地铁一号线共富新村站旁）                            ; 距离1号线共富新村站约253米
# 有2位用户正在浏览该房源
# 1.8万元/月
#
#
#
#
#
#
#
#
#
#
#
#
# 地铁10分钟
#
#
#
#
#
#
#
#
#
#
# 中航天盛 五角场金融核心 精装修带家具整层出租可分割
# 单价：5.6元/m²⋅天
#
# 中航天盛广场 / 1570m² / 中等装修
# [杨浦] - [五角场]
#                             |
#                             淞沪路619号                            ; 距离10号线支线三门路站约542米
# 有22位用户正在浏览该房源
# 26.7万元/月
#
#
#
#
#
#
#
#
#
#
#
#
# 知名物业
#
#
#
#
#
#
#
#
#
#
# 北外滩 高阳商务中心 90平米 精装修
# 单价：4.3元/m²⋅天
#
# 高阳商务中心 / 90m² / 精装修
# [虹口] - [北外滩]
#                             |
#                             东大名路879号                            ; 距离12号线提篮桥站约297米
# 有2位用户正在浏览该房源
# 1.2万元/月
#
#
#
#
#
#
#
#
#
#
#
#
# 地铁10分钟
#
#
#
#
#
#
#
#
#
#
# 五角场 中航天盛广场 275平米
# 单价：6.5元/m²⋅天
#
# 中航天盛广场 / 275m²
# [杨浦] - [五角场]
#                             |
#                             淞沪路619号                            ; 距离10号线支线三门路站约542米
# 有15位用户正在浏览该房源
# 5.4万元/月
#
#
#
#
#
#
#
#
#
#
#
#
# 知名物业
#
#
#
#
#
#
#
#
#
#
# 曲阳路（复城国际大厦）！ 现房！
# 单价：3.6元/m²⋅天
#
# 复城国际 / 238m² / 精装修
# [虹口] - [曲阳]
#                             |
#                             曲阳路910号                            ; 距离3号线大柏树站约807米
# 有22位用户正在浏览该房源
# 2.6万元/月
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 南翔 久友商务大厦 116平米 精装修
# 单价：2元/m²⋅天
#
# 久友商务大厦 / 116m² / 精装修
# [嘉定] - [南翔]
#                             |
#                             沪宜公路1158号                            ; 距离11号线主线南翔站约1910米
# 有8位用户正在浏览该房源
# 7057元/月
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 嘉定城区 弘基诚建广场 475平米 精装修
# 单价：1.8元/m²⋅天
#
# 弘基诚建广场 / 475m² / 精装修
# [嘉定] - [嘉定城区]
#                             |
#                             沪宜公路2388弄
# 有5位用户正在浏览该房源
# 2.6万元/月
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 万体馆 光启城 147平米 精装修
# 单价：5.5元/m²⋅天
#
# 光启城 / 147m² / 精装修
# [徐汇] - [万体馆]
#                             |
#                             宜山路425号                            ; 距离3号线宜山路站约320米
# 有4位用户正在浏览该房源
# 2.5万元/月
#
#
#
#
#
#
#
#
#
#
#
#
# 地铁10分钟
#
#
#
#
#
#
#
#
#
#
# 火车站 中海万锦城 57平米 中等装修
# 单价：3.9元/m²⋅天
#
# 中海万锦城 / 57m² / 中等装修
# [闸北] - [火车站]
#                             |
#                             长兴路188                            ; 距离1号线上海火车站站约582米
# 有12位用户正在浏览该房源
# 6796元/月
#
#
#
#
#
#
#
#
#
#
#
#
# 知名物业
#
#
#
#
#
#
#
#
#
#
#  尚之坊时尚文化创意园 1464.18平米 中等装修
# 单价：1.5元/m²⋅天
#
# 尚之坊时尚文化创意园 / 1464.2m² / 中等装修
# [青浦] - [其他]
#                             |
#                             崧泽大道6066号                            ; 距离17号线赵巷站站约1859米
# 有5位用户正在浏览该房源
# 6.7万元/月
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 万体馆 北海大厦 170平米 精装修
# 单价：5.6元/m²⋅天
#
# 北海大厦 / 170m² / 精装修
# [徐汇] - [万体馆]
#                             |
#                             天钥桥路859号                            ; 距离4号线上海体育场站约263米
# 有5位用户正在浏览该房源
# 2.9万元/月
#
#
#
#
#
#
#
#
#
#
#
#
# 地铁10分钟
#
#
#
#
#
#
#
#
#
#
# 九亭星汇大厦150平简装立即入住3块一平
# 单价：3元/m²⋅天
#
# 星汇大厦 / 150m²
# [松江] - [九亭/新桥]
#                             |
#                             沪松公路1223号                            ; 距离9号线九亭站约1096米
# 1.4万元/月
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 生物医药、医疗器械、汽车配件、生产加工制造等
# 单价：2.2元/m²⋅天
#
# 张江医疗器械园 / 2160m²
# [浦东] - [张江]
#                             |
#                             瑞庆路528号
# 有1位用户正在浏览该房源
# 14.5万元/月
#
#
#
#
#
#
#
#
#
#
#
#
# 南北通透
#
#
#
#
#
#
#
#
#
#
# 顾村 绿地公园广场 213.58平米 精装修
# 单价：3.3元/m²⋅天
#
# 绿地公园广场 / 213.6m² / 精装修
# [宝山] - [顾村]
#                             |
#                             陆翔路111弄                            ; 距离7号线顾村公园站约34米
# 2.1万元/月
#
#
#
#
#
#
#
#
#
#
#
#
# 地铁10分钟
#
#
#
#
#
#
#
#
#
#
# 生物医药、医疗器械、汽车配件、生产加工制造等
# 单价：1.6元/m²⋅天
#
# 张江医疗器械园 / 2303m²
# [浦东] - [张江]
#                             |
#                             瑞庆路528号
# 有1位用户正在浏览该房源
# 11.2万元/月
#
#
#
#
#
#
#
#
#
#
#
#
# 南北通透
#
#
#
#
#
#
#
#
#
#
# 人民广场 河南中路271号 251.15平米 中等装修
# 单价：7元/m²⋅天
#
# 河南中路271号 / 251.2m² / 中等装修
# [黄浦] - [人民广场]
#                             |
#                             河南中路271号                            ; 距离1号线人民广场站约389米
# 5.3万元/月
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 肇嘉浜路 乌鲁木齐南路396弄甲支弄 155平米 精装修
# 单价：6.8元/m²⋅天
#
# 乌鲁木齐南路396弄甲支弄 / 155m² / 精装修
# [徐汇] - [肇嘉浜路]
#                             |
#                             乌鲁木齐南路396弄甲支弄                            ; 距离9号线肇嘉浜路站约158米
# 有12位用户正在浏览该房源
# 3.2万元/月
#
#
#
#
#
#
#
#
#
#
#
#
# 地铁10分钟
#
#
#
#
#
#
#
#
#
#
# 金桥开发区 浦东大道2507号 162平米
# 单价：4.5元/m²⋅天
#
# 浦东大道2507号 / 162m²
# [浦东] - [金桥开发区]
#                             |
#                             浦东大道2507号                            ; 距离6号线德平路站约1641米
# 有3位用户正在浏览该房源
# 2.2万元/月
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  万荣一路60号 68平米 中等装修
# 单价：2.8元/m²⋅天
#
# 万荣一路60号 / 68m² / 中等装修
# [闸北] - [其他]
#                             |
#                             万荣一路60号                            ; 距离1号线彭浦新村站约877米
# 有3位用户正在浏览该房源
# 5791元/月
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 徐家汇 徐汇bsae航空大厦 390.1平米 精装修
# 单价：8元/m²⋅天
#
# 徐汇bsae航空大厦 / 390.1m² / 精装修
# [徐汇] - [徐家汇]
#                             |
#                             漕溪北路45号                            ; 距离1号线徐家汇站约316米
# 有7位用户正在浏览该房源
# 9.5万元/月
#
#
#
#
#
#
#
#
#
#
#
#
# 地铁10分钟
#
#
#
#
#
#
#
#
#
#
# 徐家汇 徐汇bsae航空大厦 751.14平米
# 单价：8元/m²⋅天
#
# 徐汇bsae航空大厦 / 751.1m²
# [徐汇] - [徐家汇]
#                             |
#                             漕溪北路45号                            ; 距离1号线徐家汇站约316米
# 有3位用户正在浏览该房源
# 18.3万元/月
#
#
#
#
#
#
#
#
#
#
#
#
# 地铁10分钟
#
#
#
#
#
#
#
#
#
#
# 徐家汇中心 base花园式办公 超级大花园 顶楼视野好
# 单价：8.6元/m²⋅天
#
# 徐汇bsae航空大厦 / 698.8m²
# [徐汇] - [徐家汇]
#                             |
#                             漕溪北路45号                            ; 距离1号线徐家汇站约316米
# 有9位用户正在浏览该房源
# 18.3万元/月
#
#
#
#
#
#
#
#
#
#
#
#
# 地铁10分钟
#
#
#
#
#
#
#
#
#
#
# 华漕 樽轩城市工业园区 700平米 精装修
# 单价：3元/m²⋅天
#
# 樽轩城市工业园区 / 700m² / 精装修
# [闵行] - [华漕]
#                             |
#                             闵行区纪翟路1199弄
# 有14位用户正在浏览该房源
# 6.4万元/月
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 12345678910下一页
#
#
#
#
# 上海写字楼地图找房
#
#
#
# 上海50057套
# 前往地图找房
#
#
#
# 免费委托找房
#
#
#
# 立即委托
# 已委托
# 已有392874人通过委托成功找房
#
# 查看委托进展>>
#
# 请输入正确的手机号
#
#
#
# 关闭
#
# 输入验证码
#
#
#
#
#
#
# 验证码输入错误,点击图片重新获取
#
# 验证码正确，短信已发送至
#
#
#
#
# 获取验证码
# 重新获取
#
# 验证码输入错误
#
#
# 提 交
# 提交中
# 已提交
#
#
#
# 提交成功
# 5分钟内客服将与您联系请耐心等待！
#
#
# 热门写字楼推荐
#
#
#
#
#
#
#
# 越界·世博园
# 7.0元/m²⋅天
# 黄浦 写字楼 - 黄浦世博滨江
#
#
#
#
#
#
#
#
#
# 东朔商务中心
# 4.3元/m²⋅天
# 浦东 写字楼 - 洋泾/联洋
#
#
#
#
#
#
#
#
#
# 旭辉·莘庄中心
# 3.8元/m²⋅天
# 闵行 写字楼 - 七莘路
#
#
#
#
#
#
#
#
#
# 五牛控股大厦
# 4.5元/m²⋅天
# 闸北 写字楼 - 汶水路/共和新路
#
#
#
#
#
#
#
#
#
# 紫竹数字创意港
# 2.5元/m²⋅天
# 闵行 写字楼 - 颛桥/老闵行
#
#
#
#
#
#
#
#
#
# 保辉国际大厦
# 4.3元/m²⋅天
# 杨浦 写字楼 - 五角场
#
#
#
#
#
#
#
#
#
# 凯德星贸中心
# 8.5元/m²⋅天
# 闸北 写字楼 - 火车站
#
#
#
#
#
#
#
#
#
#
#
#
#
# 展开
#
#
# 收起
#
#
# 热门写字楼：
#
# 长城金融大厦
# 日月光伯爵居A座
# 广东发展银行大厦
# 金玉兰广场
# 电科滨江中心
# 城汇大厦
# 金钟广场
# 中环广场
# 瑞安广场
# 香港新世界大厦
# 力宝广场
# 上海广场
# 博银国际大厦
# 大上海时代广场
# 东淮海国际大厦
# 久事复兴大厦
# 香港广场
# 永银大厦
#
#
#
# 区域写字楼：
#
# 浦东写字楼出租黄浦写字楼出租徐汇写字楼出租长宁写字楼出租静安写字楼出租普陀写字楼出租闸北写字楼出租虹口写字楼出租杨浦写字楼出租闵行写字楼出租宝山写字楼出租嘉定写字楼出租松江写字楼出租青浦写字楼出租奉贤写字楼出租上海周边写字楼出租
#
#
# 商圈写字楼：
#
# 八佰伴写字楼北蔡/御桥写字楼川沙写字楼金桥开发区写字楼陆家嘴写字楼南码头写字楼浦东外环写字楼三林写字楼上南地区写字楼世博滨江写字楼世纪公园写字楼外高桥写字楼洋泾/联洋写字楼竹园商贸区写字楼塘桥写字楼临港新城写字楼周浦写字楼康桥写字楼张江写字楼董家渡写字楼豫园写字楼南京东路写字楼人民广场写字楼外滩写字楼黄浦世博滨江写字楼新天地写字楼淮海中路写字楼打浦桥写字楼漕河泾/田林写字楼淮海西路写字楼龙华/徐汇滨江写字楼上海南站写字楼万体馆写字楼徐家汇写字楼肇嘉浜路写字楼北新泾写字楼虹桥火车站写字楼虹桥开发区/古北写字楼天山路写字楼延安西路写字楼中山公园写字楼北京西路写字楼曹家渡写字楼静安寺写字楼南京西路/江宁路写字楼甘泉宜川写字楼中远两湾城写字楼中山北路写字楼长风商务区写字楼长寿路写字楼真如/李子园写字楼曹杨路写字楼大宁 /延长路写字楼火车站写字楼汶水路/共和新路写字楼彭浦写字楼西藏北路写字楼北外滩写字楼大柏树写字楼凉城路/虹口足球场写字楼临平/和平公园写字楼曲阳写字楼四川北路写字楼四平路写字楼四平路写字楼鞍山写字楼控江路写字楼周家嘴写字楼东外滩写字楼平凉写字楼长阳路写字楼五角场写字楼新江湾城写字楼中原写字楼七宝写字楼七莘路写字楼莘庄写字楼颛桥/老闵行写字楼春申写字楼虹桥镇写字楼华漕写字楼南方商城写字楼浦江写字楼龙柏金汇写字楼其他写字楼淞南高境写字楼其他写字楼顾村写字楼共康写字楼共富写字楼大场写字楼安亭写字楼丰庄写字楼嘉定城区写字楼江桥写字楼南翔写字楼嘉定其他写字楼嘉定新城写字楼九亭/新桥写字楼其他写字楼泗泾写字楼松江新城/松江大学城写字楼其他写字楼青浦写字楼南桥写字楼花桥写字楼
#
#
# 写字楼城市：
#
# 北京写字楼出租
# 上海写字楼出租
# 广州写字楼出租
# 深圳写字楼出租
# 成都写字楼出租
# 武汉写字楼出租
# 杭州写字楼出租
# 西安写字楼出租
# 天津写字楼出租
# 南京写字楼出租
# 重庆写字楼出租
# 大连写字楼出租
# 福州写字楼出租
# 长沙写字楼出租
# 沈阳写字楼出租
# 郑州写字楼出租
# 无锡写字楼出租
# 合肥写字楼出租
#
#
#
# 城市共享办公：
#
# 北京联合办公
# 上海联合办公
# 广州联合办公
# 深圳联合办公
# 成都联合办公
# 武汉联合办公
# 杭州联合办公
# 西安联合办公
# 天津联合办公
# 南京联合办公
# 重庆联合办公
#
#
#
# 区域共享办公：
#
# 浦东共享办公
# 黄浦共享办公
# 徐汇共享办公
# 长宁共享办公
# 静安共享办公
# 普陀共享办公
# 闸北共享办公
# 虹口共享办公
# 杨浦共享办公
# 闵行共享办公
# 宝山共享办公
# 嘉定共享办公
# 松江共享办公
# 青浦共享办公
# 奉贤共享办公
# 上海周边共享办公
#
#
#
# 商圈共享办公：
#
# 八佰伴共享办公
# 北蔡/御桥共享办公
# 川沙共享办公
# 金桥开发区共享办公
# 陆家嘴共享办公
# 南码头共享办公
# 浦东外环共享办公
# 三林共享办公
# 上南地区共享办公
# 世博滨江共享办公
# 世纪公园共享办公
# 外高桥共享办公
# 洋泾/联洋共享办公
# 竹园商贸区共享办公
# 塘桥共享办公
# 临港新城共享办公
# 周浦共享办公
# 康桥共享办公
# 张江共享办公
# 董家渡共享办公
# 豫园共享办公
# 南京东路共享办公
# 人民广场共享办公
# 外滩共享办公
# 黄浦世博滨江共享办公
# 新天地共享办公
# 淮海中路共享办公
# 打浦桥共享办公
# 漕河泾/田林共享办公
# 淮海西路共享办公
# 龙华/徐汇滨江共享办公
# 上海南站共享办公
# 万体馆共享办公
# 徐家汇共享办公
# 肇嘉浜路共享办公
# 北新泾共享办公
# 虹桥火车站共享办公
# 虹桥开发区/古北共享办公
# 天山路共享办公
# 延安西路共享办公
# 中山公园共享办公
# 北京西路共享办公
# 曹家渡共享办公
# 静安寺共享办公
# 南京西路/江宁路共享办公
# 甘泉宜川共享办公
# 中远两湾城共享办公
# 中山北路共享办公
# 长风商务区共享办公
# 长寿路共享办公
# 真如/李子园共享办公
# 曹杨路共享办公
# 大宁 /延长路共享办公
# 火车站共享办公
# 汶水路/共和新路共享办公
# 彭浦共享办公
# 西藏北路共享办公
# 北外滩共享办公
# 大柏树共享办公
# 凉城路/虹口足球场共享办公
# 临平/和平公园共享办公
# 曲阳共享办公
# 四川北路共享办公
# 四平路共享办公
# 四平路共享办公
# 鞍山共享办公
# 控江路共享办公
# 周家嘴共享办公
# 东外滩共享办公
# 平凉共享办公
# 长阳路共享办公
# 五角场共享办公
# 新江湾城共享办公
# 中原共享办公
# 七宝共享办公
# 七莘路共享办公
# 莘庄共享办公
# 颛桥/老闵行共享办公
# 春申共享办公
# 虹桥镇共享办公
# 华漕共享办公
# 南方商城共享办公
# 浦江共享办公
# 龙柏金汇共享办公
# 其他共享办公
# 淞南高境共享办公
# 其他共享办公
# 顾村共享办公
# 共康共享办公
# 共富共享办公
# 大场共享办公
# 安亭共享办公
# 丰庄共享办公
# 嘉定城区共享办公
# 江桥共享办公
# 南翔共享办公
# 嘉定其他共享办公
# 嘉定新城共享办公
# 九亭/新桥共享办公
# 其他共享办公
# 泗泾共享办公
# 松江新城/松江大学城共享办公
# 其他共享办公
# 青浦共享办公
# 南桥共享办公
# 花桥共享办公
#
#
#
#
#
# var addEvent =  function(elem, type, handler){
#     if(elem.addEventListener){
#         elem.addEventListener(type,handler,false);
#         return handler;
#     }else if(elem.attachEvent){
#         function wrapper(event){
#             return handler.call(elem,event);
#         };
#         elem.attachEvent('on'+type,wrapper);
#         return wrapper;
#     }
# };
# window.onload=function(){
#     var exdom = document.getElementById('expand');
#     var seodom = document.getElementById('seo-content');
#     var efadom = document.getElementById('expand-father');
#     var hfadom = document.getElementById('hide-father');
#     var hidom = document.getElementById('hide');
#     var expFun = function(){
#         seodom.style.height = '';seodom.style.overflow = 'auto';
#         efadom.style.display = 'none';
#         hfadom.style.display = '';
#     };
#     var hidFun = function(){
#         seodom.style.height = '30px';seodom.style.overflow = 'hidden';
#         hfadom.style.display = 'none';
#         efadom.style.display = '';
#     };
#     addEvent(exdom,'click',expFun);
#     addEvent(hidom,'click',hidFun);
# };
#
#
#
#
#
# ◆
#
#
#
#
#
#
#
# 免费咨询
#
# ◆
# 免费咨询
# 400-733-2233
# 110万+套精品房源
# 1000+人专业顾问
# 早8:00-晚21:00
#
#
#
#
#
# 委托找房
# ◆免费委托，专业服务
#
#
#
#
# 我的收藏
# ◆我的收藏
#
#
# -
#
#
#
# ◆最近浏览
#
#
#
# -
#
#
#
# ◆
#
#
# 下载好租APP
#
#
#
# 扫码进入好租小程序
#
#
#
# -
#
#
#
# ◆投放房源
#
#
#
#
#
#
# ◆返回顶部
#
#
#
#
#
#
#         免费咨询
#
#
#         400-733-2233
#
#
#
# 办公选址上好租，专业靠谱！
#
# 关于好租-
# 服务介绍-
# 联系我们-
# 网站地图-
# 加入我们-
# 常见问题
# -
# 友情链接
# -
# 广告服务
# -
# 投放房源
#
# ©2015-2019 北京好租科技发展有限公司 京ICP备16019026号 地址：北京市海淀区上地软件园南路57号八维学院
#
# 客服服务：（早8:00-晚21:00）
# 400-733-2233
#
#
#
# 扫码下载好租APP
#
#
#
# 扫码进入好租小程序
#
#
# SOCIAL MEDIA
# facebook
# twitter
# linkin
#
#
#
#
# 京公网安备 11010802025685号
#
#
#
#
# 	 HZ.use('static/js/common/widget.js',function(Widget){
# 	        Widget.initWidgets();
# 	    });
# 	 (function(){document.getElementById('___szfw_logo___').oncontextmenu = function(){return false;};document.getElementById('___szfw_logo1___').oncontextmenu = function(){return false;}})();
#
#
#     var piwiktj = 'city=13@channel=1@e_type=2@terminal=1@type=@dataNum=50057@sugstNum=0@page=1';
#     if (piwiktj) {
#         _paq.push(['trackEvent', 'list', 'houselist_filter', piwiktj]);
#     }
#
#     var $activityPiwik = '';
#     if ($activityPiwik) {
#         _paq.push(['trackEvent', 'ideal_office', 'list_show', $activityPiwik]);
#     }
#
#         _paq.push(['trackEvent', 'houselist', '_house_show', 'channel=1@city=13@e_type=2@terminal=1@ids=506526,1036094,848030,897321,318118,678807,1033957,327534,756378,1130531,1130452,1100144,955018,1069399,937323,1114050,1139176,1093699,1116298,408443,1202355,654447,1082377,1134770,1082391,1066907,1132933,913063,918729,1185158,1185153,1185171,946138']);

# %%
from bs4 import BeautifulSoup
import requests
import pandas
import re
import execjs
print("https://www.haozu.com/sh/house-list/")
prefix = 'https://www.haozu.com/sh/house-list/'
# prefix = 'https://www.baidu.com'
# headers={
#         'Connection': 'Keep-Alive',
#         'Accept': 'text/html, application/xhtml+xml, */*',
#         'Accept-Language': 'en-US,en;q=0.8,zh-Hans-CN;q=0.5,zh-Hans;q=0.3',
#         'User-Agent': 'Mozilla/5.0 (Windows NT 6.3; WOW64; Trident/7.0; rv:11.0) like Gecko'
#      }
proxy_ip = 'https://111.181.50.95:9999'
# proxies = {'https': proxy_ip}
# res = requests.get(prefix, proxies=proxies)
print( requests)
res = requests.get(prefix)
print(res)
# Out:
# https://www.haozu.com/sh/house-list/
# <module 'requests' from 'c:\\python\\python36\\lib\\site-packages\\requests\\__init__.py'>
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# c:\python\python36\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#
# c:\python\python36\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      79     if err is not None:
# ---> 80         raise err
#      81
#
# c:\python\python36\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      69                 sock.bind(source_address)
# ---> 70             sock.connect(sa)
#      71             return sock
#
# TimeoutError: [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# c:\python\python36\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# c:\python\python36\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#
# c:\python\python36\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     838         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 839             conn.connect()
#     840
#
# c:\python\python36\lib\site-packages\urllib3\connection.py in connect(self)
#     300         # Add certificate verification
# --> 301         conn = self._new_conn()
#     302         hostname = self.host
#
# c:\python\python36\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     167             raise NewConnectionError(
# --> 168                 self, "Failed to establish a new connection: %s" % e)
#     169
#
# NewConnectionError: <urllib3.connection.VerifiedHTTPSConnection object at 0x0000020753134F60>: Failed to establish a new connection: [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# c:\python\python36\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# c:\python\python36\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# c:\python\python36\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     397         if new_retry.is_exhausted():
# --> 398             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     399
#
# MaxRetryError: HTTPSConnectionPool(host='www.haozu.com', port=443): Max retries exceeded with url: /sh/house-list/ (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x0000020753134F60>: Failed to establish a new connection: [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。',))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-39-3597b4720b4b> in <module>
#      17 # res = requests.get(prefix, proxies=proxies)
#      18 print( requests)
# ---> 19 res = requests.get(prefix)
#      20 print(res)
#
# c:\python\python36\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# c:\python\python36\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# c:\python\python36\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# c:\python\python36\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# c:\python\python36\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='www.haozu.com', port=443): Max retries exceeded with url: /sh/house-list/ (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x0000020753134F60>: Failed to establish a new connection: [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。',))
