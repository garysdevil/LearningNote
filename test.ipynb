# %%
import requests
import random
proxyHttp = [
    {'http': 'http://119.101.115.75:9999'},
    {'http': 'http://223.215.101.254:9999'}
]
proxyHttps = {
    'https': 'https://221.1.200.242:38652' ,
    'https': 'https://119.101.116.219:9999'
}

head = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36', 
             'Connection': 'keep-alive'}

url = 'https://www.haozu.com/sh/'
url1 = 'http://139.224.115.177:7777'
url2 = 'https://icanhazip.com'  # http://icanhazip.com会返回当前的IP地址
proxy = random.choice(proxyHttp)
print('proxy:',proxy)
p = requests.get(url1, headers=head, proxies = proxy)
print(p.text)
# Out:
# proxy: {'http': 'http://223.215.101.254:9999'}
# Hello World

# %%
# 最简单的爬虫程序demo , 适用于静态的,没有防爬虫策略的网站
import requests # 发送网络请求，获取响应内容
from bs4 import BeautifulSoup  # 对于网站响应的html进行解析 和数据的清洗
import pandas # 数据可视化，保存数据

# 要爬取的网页的网站
url = 'https://news.qudong.com/yejie/'

# 1 获取网页内容
req = requests.get(url) # 进行网络请求，获取响应的内容
req.encoding = 'utf8' # 设置解析编码,防止中文乱码
contentAll = req.text # 解析为文本

# 2 清洗数据，处理
soup = BeautifulSoup(contentAll,'html.parser') # 创建 beautifulsoup对象
contentList = soup.select('.text h4 ') # 根据css帅选数据,得到一个嵌套着beautifulsoup对象的列表
print(type(contentList))

# 为了更好的进行数据的保存与展示，将数据保存在嵌套字典的列表里
all = [] # 
for item in contentList: # 循环获取文本数据
    all.append({'title':item.text}) 

    
# 3 保存数据
# 使用pandas库函数，将数据导入excel
all = pandas.DataFrame(all)
all.to_excel('./content.xlsx')
all.head(1000) #展示数据
# Out:
# <class 'list'>
#                                               title
# 0   驱动中国晚报|Redmi发布首款手机红米Note7   华强北店铺：iPhone不会便宜这么多
# 1                           谷歌搜索被曝可任意修改搜索结果，已存在三年之久
# 2                         《时代周刊》发布50项最佳发明设计 你最需要哪个？
# 3                     2018年十大消费维权舆情热点发布，顺风车安全问题高居榜首
# 4                           滴滴就“一键报警”展开深度警企联动 广东先行！
# 5                2018年十大消费维权舆情热点公布：顺风车、信息安全等领域成关注焦点
# 6                                聊天宝能为垂死的罗永浩和锤子续命吗？
# 7                             街电因两项专利侵权被判赔偿来电3000万元
# 8                         优酷否认被今日头条收购，起诉鞭牛士并索赔1000万
# 9                          冰箱空调新国标实施，京品家电囊括所有首批达标产品
# 10                    全国“扫黄打非”办公室公布：2018年“扫黄打非”十大案件
# 11                         全球首辆纯3D打印的电动摩托车 骑上去酷到没朋友
# 12                             10个“支付宝”为全球10亿用户提供服务
# 13                               网购省钱APP排名 苏宁第一京东第五
# 14                           今日头条收购优酷？优酷：完全是子虚乌有的胡扯
# 15  驱动中国昨夜今晨：传苹果手机开始在华降价销售 AMD发布7nm第三代锐龙和Radeon VII
# 16                   网络短视频平台管理规范发布：不得未经授权自行剪切电视剧等作品
# 17              2019 CES中国身影：百度AI进阶方案到场，京东秀出未来零售黑科技
# 18                     今日头条保险产品“夭折”：上线十天匆忙下架 或踩监管红线
